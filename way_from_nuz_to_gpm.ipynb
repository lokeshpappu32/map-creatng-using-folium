# %%
import folium

# %%
map=folium.Map(location=[16.793809042070425, 80.82677354134124])
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
from branca.element import Figure

# %%
fig=Figure(width=1000,height=1000)
map1=folium.Map(location=[16.793809042070425, 80.82677354134124])
fig.add_child(map1)
#colleges
folium.Marker(location=[17.230329335321276,82.20625400851902],tooltip="College",icon=folium.Icon(color="orange",prefix='fa',icon='institution')).add_to(map1)
folium.Marker(location=[17.238733931498206,82.1523126909038],tooltip="College",color="orange",icon=folium.Icon(color="orange",prefix='fa',icon='university')).add_to(map1)
folium.Marker(location=[17.162151476654586,82.02842667395011],tooltip="College",color="orange",icon=folium.Icon(color="orange",prefix='fa',icon='university')).add_to(map1)
folium.Marker(location=[17.098092147058384,81.91637065006334],tooltip="College",color="orange",icon=folium.Icon(color="orange",prefix='fa',icon='university')).add_to(map1)
folium.Marker(location=[17.08477460125244,81.90636314447734],tooltip="College",color="orange",icon=folium.Icon(color="orange",prefix='fa',icon='university')).add_to(map1)
folium.Marker(location=[16.73732039349146,81.14221081772597],tooltip="College",color="orange",icon=folium.Icon(color="orange",prefix='fa',icon='university')).add_to(map1)
folium.Marker(location=[16.787141530641673,80.82504191927768],tooltip="College",color="orange",icon=folium.Icon(color="orange",prefix='fa',icon='university')).add_to(map1)
folium.Marker(location=[17.380126333217163, 82.56617849167506],tooltip="College",color="orange",icon=folium.Icon(color="orange",prefix='fa',icon='university')).add_to(map1)
#SHOPS
folium.Marker([17.315394003035976, 82.36424281319853],tooltip="Shop",icon=folium.Icon(color="blue",prefix='fa',icon='shopping-basket')).add_to(map1)
folium.Marker([17.31504575379701, 82.36299826821772],tooltip="Shop",color="blue",icon=folium.Icon(color="blue",prefix='fa',icon='shopping-basket')).add_to(map1)
folium.Marker([17.309145902002225, 82.36503674706204],tooltip="Shop",color="blue",icon=folium.Icon(color="blue",prefix='fa',icon='shopping-basket')).add_to(map1)
folium.Marker([17.281487823631284, 82.35537006577769],tooltip="Shop",color="blue",icon=folium.Icon(color="blue",prefix='fa',icon='shopping-basket')).add_to(map1)
folium.Marker([17.250259934577993, 82.3400814743905],tooltip="Shop",color="blue",icon=folium.Icon(color="blue",prefix='fa',icon='shopping-basket')).add_to(map1)
folium.Marker([17.17348528653607, 82.05706884499943],tooltip="Shop",color="blue",icon=folium.Icon(color="blue",prefix='fa',icon='shopping-basket')).add_to(map1)
folium.Marker([17.062220941447745, 81.87094142706638],tooltip="Shop",color="blue",icon=folium.Icon(color="blue",prefix='fa',icon='shopping-basket')).add_to(map1)
folium.Marker([17.815582080095933, 83.11277474133848],tooltip="Shop",color="blue",icon=folium.Icon(color="blue",prefix='fa',icon='shopping-basket')).add_to(map1)
folium.Marker([18.12647905338653, 83.39704596338005],tooltip="Shop",color="blue",icon=folium.Icon(color="blue",prefix='fa',icon='shopping-basket')).add_to(map1)
folium.Marker([17.089808327216634, 81.88367927672941],tooltip="Shop",color="blue",icon=folium.Icon(color="blue",prefix='fa',icon='shopping-basket')).add_to(map1)
folium.Marker([17.840398395997944, 83.09577440185419],tooltip="Shop",color="blue",icon=folium.Icon(color="blue",prefix='fa',icon='shopping-basket')).add_to(map1)
#Restaurents
folium.Marker([17.318753549881798, 82.36383511743011],tooltip="Restaurent",icon=folium.Icon(color="red",prefix='fa',icon='bed')).add_to(map1)
folium.Marker([17.226477100919837, 82.23593143876607],tooltip="Restaurent",icon=folium.Icon(color="red",prefix='fa',icon='bed')).add_to(map1)
folium.Marker([17.229443534542654, 82.20508934192947],tooltip="Restaurent",icon=folium.Icon(color="red",prefix='fa',icon='bed')).add_to(map1)
folium.Marker([17.199509212537073, 82.09649496601322],tooltip="Restaurent",icon=folium.Icon(color="red",prefix='fa',icon='bed')).add_to(map1)
folium.Marker([17.189145410869845, 82.07824852270083],tooltip="Restaurent",icon=folium.Icon(color="red",prefix='fa',icon='bed')).add_to(map1)
folium.Marker([17.146365416908345, 81.98030868931217],tooltip="Restaurent",icon=folium.Icon(color="red",prefix='fa',icon='bed')).add_to(map1)
folium.Marker([17.127321439038397, 81.935307266219],tooltip="Restaurent",icon=folium.Icon(color="red",prefix='fa',icon='bed')).add_to(map1)
folium.Marker([17.02880438056287, 81.81570457064106],tooltip="Restaurent",icon=folium.Icon(color="red",prefix='fa',icon='bed')).add_to(map1)
folium.Marker([17.92699977139697, 83.39356445124825],tooltip="Restaurent",icon=folium.Icon(color="red",prefix='fa',icon='bed')).add_to(map1)
folium.Marker([17.721939343563747, 83.00866933222822],tooltip="Restaurent",icon=folium.Icon(color="red",prefix='fa',icon='bed')).add_to(map1)
folium.Marker([17.575348098327765, 82.8375875424053],tooltip="Restaurent",icon=folium.Icon(color="red",prefix='fa',icon='bed')).add_to(map1)
folium.Marker([17.392498060092578, 82.52886502167416],tooltip="Restaurent",icon=folium.Icon(color="red",prefix='fa',icon='bed')).add_to(map1)
#Ambulance
folium.Marker([16.780355071248003, 80.87111662130405],tooltip="Ambulance",icon=folium.Icon(color="yellow",prefix='fa',icon='ambulance')).add_to(map1)
folium.Marker([17.029200944213013, 81.65744060826309],tooltip="AMBUALANCE",icon=folium.Icon(color="yellow",prefix='fa',icon='ambulance')).add_to(map1)
folium.Marker([17.137997848838136, 81.9706247022553],tooltip="ambulance",icon=folium.Icon(color="yellow",prefix='fa',icon='ambulance')).add_to(map1)
folium.Marker([17.406751126075356, 82.54025975054586],tooltip="ambulance",icon=folium.Icon(color="yellow",prefix='fa',icon='ambulance')).add_to(map1)
folium.Marker([16.77668756479255, 81.13950300214474],tooltip="ambulance",icon=folium.Icon(color="yellow",prefix='fa',icon='ambulance')).add_to(map1)
folium.Marker([17.7262078458621, 83.14176124738081],tooltip="ambulance",icon=folium.Icon(color="yellow",prefix='fa',icon='ambulance')).add_to(map1)
folium.Marker([18.261715535588127, 83.30106302874731],tooltip="ambulance",icon=folium.Icon(color="yellow",prefix='fa',icon='ambulance')).add_to(map1)
#Bus
folium.Marker([17.15615458077956, 82.00381770017582],tooltip="Bus",icon=folium.Icon(color="green",prefix='fa',icon='bus')).add_to(map1)
folium.Marker([17.2373331920597, 82.17920786206287],tooltip="BUS",icon=folium.Icon(color="green",prefix='fa',icon='bus')).add_to(map1)
folium.Marker([17.230864933718838, 82.12595671724252],tooltip="BUS",icon=folium.Icon(color="green",prefix='fa',icon='bus')).add_to(map1)
folium.Marker([17.811331884339317, 83.209721948613],tooltip="BUS",icon=folium.Icon(color="green",prefix='fa',icon='bus')).add_to(map1)
folium.Marker([17.855780246780526, 82.93094391919753],tooltip="BUS",icon=folium.Icon(color="green",prefix='fa',icon='bus')).add_to(map1)
#Industry
folium.Marker([17.23622083253235, 82.142240481647322],tooltip="iNDUSTRY",icon=folium.Icon(color="pink",prefix='fa',icon='industry')).add_to(map1)
folium.Marker([18.119225873520406, 83.4047260546031],tooltip="iNDUSTRY",icon=folium.Icon(color="pink",prefix='fa',icon='industry')).add_to(map1)
folium.Marker([17.908964378513264, 83.389619854398],tooltip="iNDUSTRY",icon=folium.Icon(color="pink",prefix='fa',icon='industry')).add_to(map1)
folium.Marker([17.71022747473393, 83.01883128202489],tooltip="iNDUSTRY",icon=folium.Icon(color="pink",prefix='fa',icon='industry')).add_to(map1)
#Bike
folium.Marker([17.04924434597482, 81.85318268345692],tooltip="Bike",icon=folium.Icon(color="black",prefix='fa',icon='industry')).add_to(map1)
folium.Marker([17.227690134015543, 82.23388184529905],tooltip="Bike",icon=folium.Icon(color="black",prefix='fa',icon='industry')).add_to(map1)
folium.Marker([17.03709599393475, 81.83218136670901],tooltip="Bike",icon=folium.Icon(color="black",prefix='fa',icon='automobile')).add_to(map1)
folium.Marker([17.310784768694216, 82.3642535420326],tooltip="Bike",icon=folium.Icon(color="black",prefix='fa',icon='automobile')).add_to(map1)
folium.Marker([17.793535066685937, 83.09161248267347],tooltip="Bike",icon=folium.Icon(color="black",prefix='fa',icon='automobile')).add_to(map1)
folium.Marker([17.792227463821447, 83.25366081214644],tooltip="Bike",icon=folium.Icon(color="black",prefix='fa',icon='automobile')).add_to(map1)

map1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:39: UserWarning: color argument of Icon should be one of: {'lightgreen', 'red', 'darkpurple', 'lightgray', 'purple', 'lightred', 'darkgreen', 'cadetblue', 'green', 'orange', 'darkblue', 'gray', 'blue', 'lightblue', 'pink', 'white', 'beige', 'black', 'darkred'}.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:40: UserWarning: color argument of Icon should be one of: {'lightgreen', 'red', 'darkpurple', 'lightgray', 'purple', 'lightred', 'darkgreen', 'cadetblue', 'green', 'orange', 'darkblue', 'gray', 'blue', 'lightblue', 'pink', 'white', 'beige', 'black', 'darkred'}.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: color argument of Icon should be one of: {'lightgreen', 'red', 'darkpurple', 'lightgray', 'purple', 'lightred', 'darkgreen', 'cadetblue', 'green', 'orange', 'darkblue', 'gray', 'blue', 'lightblue', 'pink', 'white', 'beige', 'black', 'darkred'}.
# ...

# %%
cord=[
[16.793809042070425, 80.82677354134124],
[16.772772339174498, 80.87621201772004],
[16.756993283970438, 80.8926915098463],
[16.73332224800549, 80.90642441995153],
[16.683340408904293, 80.94487656824616],
[16.691233148090067, 80.97783555249869],
[16.696494793112095, 81.00530137270913],
[16.709648271516308, 81.03276719291958],
[16.735952508391005, 81.05748643110898],
[16.75173330806359, 81.11516465355093],
[16.73858273246871, 81.10692490748778],
[16.73858273246871, 81.12340439961405],
[16.746473186804536, 81.13713730971928],
[16.76225311448473, 81.17833604003495],
[16.814843414173485, 81.24974717258212],
[16.849019291057658, 81.27446641077152],
[16.901585506314497, 81.34038437927659],
[16.92523552605945, 81.3596104534239],
[16.95676426468765, 81.40355576576061],
[16.977780485908415, 81.49144639043404],
[17.01455320891393, 81.50792588256031],
[17.0486928436998, 81.54088486681285],
[17.043440997875635, 81.57933701510747],
[17.03293686352584, 81.62602890946523],
[17.030310737738095, 81.71391953413865],
[17.030310737738095, 81.75511826445432],
[17.053944541903522, 81.80455674083315],
[17.043440997875635, 81.84026230710673],
[17.0486928436998, 81.86772812731716],
[17.069698750392295, 81.86772812731716],
[17.10907845040626, 81.91991318571701],
[17.14582532237739, 81.98033799017999],
[17.172068638100892, 82.04900254070611],
[17.23503743343041, 82.16435898558998],
[17.22966384853255, 82.21857204175717],
[17.219170232648146, 82.26938380914649],
[17.230319679740234, 82.30714931193586],
[17.231631335171148, 82.30302943890429],
[17.241468454004462, 82.32362880406214],
[17.24474737715628, 82.33530177765158],
[17.25261655505932, 82.34148158719891],
[17.26245255544274, 82.34285487820944],
[17.266386808699327, 82.34972133326205],
[17.27753340355449, 82.35109462427256],
[17.28015603375393, 82.35521449730416],
[17.297857810563055, 82.36070766134623],
[17.303758024457412, 82.36551417988306],
[17.31031359567369, 82.3648275343778],
[17.315557884344113, 82.36276759786202],
[17.324735029409556, 82.36551417988306],
[17.331289852325067, 82.36276759786202],
[17.33030664402686, 82.36165179916982],
[17.33333818722045, 82.36141576488664],
[17.22229543903643, 82.2522446071942],
[17.368725860143112, 82.55075862324492],
[17.418381080132175, 82.72740223824741],
[17.47194131024881, 82.76985147906197],
[17.55943263614051, 82.84516464824908],
[17.652101211566613, 82.91773918776111],
[17.808615662751066, 83.15326401714127],
[17.87248633277139, 83.29019705202691],
[17.935031267014192, 83.42028343516827],
[18.050941496426677, 83.39700481923771],
[18.03922370697861, 83.39837416045327],
[18.121231858570304, 83.38878884801127],
[18.158968746745607, 83.37920353556927],
[18.20450241140605, 83.36687956242957],
[18.230516308287964, 83.35318625894102],
[18.27993199239305, 83.33264630370817]]

# %%
f1=folium.FeatureGroup("Path1")

line=folium.vector_layers.PolyLine(cord,popup='<b>PATH</b>',tooltip='NZD TO ANV',color='blue',weight=10).add_to(f1)

f1.add_to(map1)

folium.LayerControl().add_to(map1)

map1
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...
